# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# Load data from CSV file
data = pd.read_csv('customer_data.csv')

# Handle missing values
data['age'].fillna(data['age'].mean(), inplace=True)
data['income'].fillna(data['income'].median(), inplace=True)

# Remove duplicates
data.drop_duplicates(inplace=True)

# Convert categorical variables to numerical
data = pd.get_dummies(data, columns=['gender', 'occupation'])

# Scale numerical features
scaler = StandardScaler()
numerical_features = ['age', 'income']
data[numerical_features] = scaler.fit_transform(data[numerical_features])

# Display the first few rows and info of the dataset
print(data.head())
print(data.info())
# Out:
#    CustomerID       age    income  Spending Score (1-100)  Work Experience  \
# 0           1 -1.054089 -2.093501                      39                1
# 1           2 -0.983723 -1.656133                      81                3
# 2           3 -1.018906 -0.540845                       6                1
# 3           4 -0.913356 -1.131292                      77                0
# 4           5 -0.631891 -1.590528                      40                2
#
#    Family Size  gender_Female  gender_Male  occupation_Artist  \
# 0            4          False         True              False
# 1            3          False         True              False
# 2            1           True        False              False
# 3            2           True        False              False
# 4            6           True        False              False
#
#    occupation_Doctor  occupation_Engineer  occupation_Entertainment  \
# 0              False                False                     False
# 1              False                 True                     False
# 2              False                 True                     False
# 3              False                False                     False
# 4              False                False                      True
#
#    occupation_Executive  occupation_Healthcare  occupation_Homemaker  \
# 0                 False                   True                 False
# 1                 False                  False                 False
# 2                 False                  False                 False
# 3                 False                  False                 False
# 4                 False                  False                 False
#
#    occupation_Lawyer  occupation_Marketing
# 0              False                 False
# 1              False                 False
# 2              False                 False
# 3               True                 False
# 4              False                 False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                2000 non-null   int64
#  1   age                       2000 non-null   float64
#  2   income                    2000 non-null   float64
#  3   Spending Score (1-100)    2000 non-null   int64
#  4   Work Experience           2000 non-null   int64
#  5   Family Size               2000 non-null   int64
#  6   gender_Female             2000 non-null   bool
#  7   gender_Male               2000 non-null   bool
#  8   occupation_Artist         2000 non-null   bool
#  9   occupation_Doctor         2000 non-null   bool
#  10  occupation_Engineer       2000 non-null   bool
#  11  occupation_Entertainment  2000 non-null   bool
#  12  occupation_Executive      2000 non-null   bool
#  13  occupation_Healthcare     2000 non-null   bool
#  14  occupation_Homemaker      2000 non-null   bool
#  15  occupation_Lawyer         2000 non-null   bool
#  16  occupation_Marketing      2000 non-null   bool
# dtypes: bool(11), float64(2), int64(4)
# memory usage: 115.4 KB
# None
